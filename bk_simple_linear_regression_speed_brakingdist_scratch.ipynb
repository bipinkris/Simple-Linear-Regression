# %%
import pandas as mypandas
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
#Import the Data.
myData = mypandas.read_csv('mycar.csv')
myData
# Out:
#     Speed  Stopping_dist
# 0       4              2
# 1       4             10
# 2       7              4
# 3       7             22
# 4       8             16
# 5       9             10
# 6      10             18
# 7      10             26
# 8      10             34
# 9      11             17
# 10     11             28
# 11     12             14
# 12     12             20
# 13     12             24
# 14     12             28
# 15     13             26
# 16     13             34
# 17     13             34
# 18     13             46
# 19     14             26
# 20     14             36
# 21     14             60
# 22     14             80
# 23     15             20
# 24     15             26
# 25     15             54
# 26     16             32
# 27     16             40
# 28     17             32
# 29     17             40
# 30     17             50
# 31     18             42
# 32     18             56
# 33     18             76
# 34     18             84
# 35     19             36
# ...

# %%
X=myData.iloc[:,0].values
Y=myData.iloc[:,1]

# %%
plt.scatter(X,Y)
X.shape
# Out:
# (49,)

# %%
plt.scatter(X,Y)

#Gradient Descent Algorithm:
Q1 =0 #slope 
Q0 = 0 #constant
alpha = 0.0001
m= float(len(X))

#repeat until convergence
for i in range(2000):
    Y_pred  = Q1*X+Q0
    Y_pred.shape
    #plt.plot(X,Y_pred,color='b')
    #Derivate with respect with Q1(slope)
    DQ1 = (1/m) *sum(X*(Y_pred-Y))
    #Derivate with respect with Q0(constant)
    DQ0 = (1/m)* sum(Y_pred-Y)
    #Test for convergence
    if DQ1 == 0:
        break 
        
    #Calculate Q1 & Q0
    Q1 = Q1-alpha*DQ1
    Q0 = Q0-alpha*DQ0

#Print Coefficient(slope), Y Intercept(constant)
print (Q1,Q0)
#plot the best regression line
plt.plot(X,Y_pred,color='black')
plt.title('Speed Vs Braking Dist')
plt.xlabel('Speed')
plt.ylabel('Braking Dist')

Y_pred.shape
# Out:
# 2.820730093559797 -0.12060073911131837
# (49,)

# %%
Y.shape
# Out:
# (49,)
